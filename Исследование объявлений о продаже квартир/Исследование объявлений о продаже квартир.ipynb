# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color = "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Данила :)
#
# Спасибо за работу на проекте, за все исправления и комментарии
#
#
#
# Подведем итоги, мы научились и повторили на проекте каким образом:
#
# + читать тех. задание проекта
# + исследовать неочищенные данные
# + выдвигать гипотезы о пропусках данных и заполнять их значениями
# + принимать решения об удалении некачественных данных
# + находить аномалии в данных и отделять редкие значения
# + соглашаться с наличием пропусков в данных и не забывать об их наличии при фильтрации
# + строить информативные визуализации
# + делить одну выборку на две части
# + находить зависимости и распределения в данных
# + формировать выводы
#
# Навыки отработаны, проект принят
#
# <b>Поздравляю с успешно сданным третьим проектом на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color = "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />
#
# добавил бонус

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />   Привет, Данила :) Спасибо за доработки
#
# Критические ❌ комментарии
#
# + завершить фильтрацию редких значений в п. 2.4
# + добавить два графика в п. 4.3
# + поправить исследование аномалии 27-го км.  в п.4.5
#
# подсказки добавил

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Данила :) Спасибо, что прислал задание :) Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://devpractice.ru/matplotlib-book/">“Библиотека Matplotlib” доступна для скачивания БЕСПЛАТНО!</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос ...

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Название, краткое вступление в работу и главная задача зафиксированы.
#
# Четкий план работ и перечень основных задач позволит коллегам быстрее вникнуть в суть проекта, + будет легче  идти к главной цели проекта

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import warnings

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Молодец, что делишь блоки загрузки библиотек и датасета, в случае необходимости добавления новых библиотек не придется загружать весь датасет заново и перезапускать проект целиком

# %%
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %%
df.tail(15)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23684            20  21400000.0      145.00  2018-11-02T00:00:00      4
# 23685            15   2490000.0       31.00  2019-01-24T00:00:00      1
# 23686             8   3300000.0       31.00  2017-04-29T00:00:00      1
# 23687             6   3200000.0       39.00  2017-12-16T00:00:00      1
# 23688            19   9200000.0      101.00  2019-04-01T00:00:00      3
# 23689            13   3550000.0       35.30  2018-02-28T00:00:00      1
# 23690             3   5500000.0       52.00  2018-07-19T00:00:00      2
# 23691            11   9470000.0       72.90  2016-10-13T00:00:00      2
# 23692             2   1350000.0       30.00  2017-07-07T00:00:00      1
# 23693             9   4600000.0       62.40  2016-08-05T00:00:00      3
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# ...

# %%
df.info()
records_count = df.shape[0]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
df.hist(figsize=(15, 20), bins=50);

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Убрать служ. информацию поможет точка с запятой на посл. строке кода
#
#     array([[<AxesSubplot:title={'center':'total_images'}>,
#         <AxesSubplot:title={'center':'last_price'}>,
#         <AxesSubplot:title={'center':'total_area'}>,
#         <AxesSubplot:title={'center':'rooms'}>],
#        [<AxesSubplot:title={'center':'ceiling_height'}>,
#         <AxesSubplot:title={'center':'floors_total'}>,
#         <AxesSubplot:title={'center':'living_area'}>,
#         <AxesSubplot:title={'center':'floor'}>],
#        [<AxesSubplot:title={'center':'kitchen_area'}>,
#         <AxesSubplot:title={'center':'balcony'}>,
#         <AxesSubplot:title={'center':'airports_nearest'}>,
#         <AxesSubplot:title={'center':'cityCenters_nearest'}>],
#        [<AxesSubplot:title={'center':'parks_around3000'}>,
#         <AxesSubplot:title={'center':'parks_nearest'}>,
#         <AxesSubplot:title={'center':'ponds_around3000'}>,
#         <AxesSubplot:title={'center':'ponds_nearest'}>],
#        [<AxesSubplot:title={'center':'days_exposition'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)
#
# data.hist(figsize=(15, 20));

# %% [markdown]
# **Общий вывод после первичного изучения данных**:
#
# * Столбец first_day_exposition: тип object, должен быть datetime.
# * Столбец ceiling_height: NaN значения. На гистограмме видны необоснованно большие значения, что усложноит предобработку данных
# * Столбец floors_total: должен быть тип int64, NaN значения.
# * Столбец living_area: NaN значения.
# * Столбец is_apartment: NaN значения.
# * Столбец kitchen_area: NaN значения.
# * Столбец balcony: NaN значения.
# * Столбец locality_name: NaN значения.
# * Cтолбец airports_nearest: NaN значения.
# * Столбец cityCenters_nearest: NaN значения.
# * Столбец parks_around3000: NaN значения, должен быть тип int64.
# * Столбец parks_nearest: NaN значения.
# * Столбец ponds_around3000: NaN значения, должен быть тип int64.
# * Столбец ponds_nearest: NaN значения.
# * Столбец days_exposition: NaN значения, должен быть тип int64.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> загрузка и обзор данных проведены корректно

# %% [markdown]
# ### Предобработка данных

# %%
# check
# пропущенные значения бары

def pass_value_barh(data):
    try:
        (
            (data.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind = 'barh', figsize = (19,6), rot = -5, legend = False, fontsize = 16)
            .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) или произошла ошибка в первой части функции ')

# %%
pass_value_barh(df)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Наглядность представления информации одна из важных составляющих работы дата-аналитика или дата-сайентиста
#
# мой график оформлен не совсем корректно, сможешь отметить, что стоило бы исправить в графике?

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# За поворот текста отвечает параметр rot, можно добавить обозначение оси х (процент записей с пропусками)
#
#         df.isna().mean()*100 — для расчета процента пропусков в колонке
#
# На графике мы оцениваем масштаб проблемы с пропусками и возможное совпадение % пропущенных значений в колонках
#
# добавить подписи к осям мешает строка кода
#
#         .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')
#
# её стоит заменить на
#
#         plt.title('Пропущенные значения, %' + "\n", fontsize=22, color='SteelBlue')
#         plt.xlabel('Процент пропусков', fontsize=22)
#         plt.ylabel('Столбцы с пропусками')
#
# плюс установка шкалы от 0 до 100
#
#         plt.xlim(0, 100)

# %%
df.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'cityCenters_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# **Преобразуем формат даты в столбце first_day_exposition. Так, как время везде проставлено на 00:00:00, мы имеем право пренебречь временем и оставить только дату.**

# %%
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format='%Y-%m-%d')

# %% [markdown]
# **Меняем тип данных в столбце days_exposition на int, а также заменим все пропуски нулем. Тоже самое делаем со столбцом balcony**

# %%
df['days_exposition'] = df['days_exposition'].fillna(0).astype('int')
df['balcony'] = df['balcony'].fillna(0).astype('int')

# %% [markdown]
# **В предварительном анализе данных мною было замечено, что столбец is_apartment почти целиком состоит из NaN. Это может свидетельствовать о том, что данный столбец добавили уже к существующим данным, не проставив значение по умолчанию. Заменим отсутствующие значения на False**

# %%
df['is_apartment'] = df['is_apartment'].fillna(False)

# %% [markdown]
# **Для удобства восприятия цен, приведем их к типу int**

# %%
df['last_price'] = df['last_price'].astype('int')
df = df.dropna(subset=['floors_total'])
df['floors_total'] = df['floors_total'].astype('int')

# %%
df.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9118
# floors_total                0
# living_area              1870
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area             2231
# balcony                     0
# locality_name              48
# airports_nearest         5532
# cityCenters_nearest      5509
# parks_around3000         5508
# parks_nearest           15568
# ponds_around3000         5508
# ponds_nearest           14552
# days_exposition             0
# dtype: int64

# %% [markdown]
# **В результате заполнения явных пропусков, общее количество пропусков уменьшилось. Последовательно опишу каждый столбец и возможность заполнить в нем пропуски.**
#
# * **ceiling_height**: 9195 пропусков. Данные разнятся от 1 метра до 100. Такой разброс в данных создает выбросы, что не позволяет нам использовать для заполнения пропусков среднее значение. Будем использовать медианное значение для каждого города отдельно. Также, избавимся от аномальных значений. Примем за константу, что высота потолка не может быть больше 5 метров.
# * **floors_total**: слишком малое количество пропусков, на исследование это не повлияет. Оставляем.
# * **living_area**: пропусков 1903, что является колоссальным количеством. Возможно, пользователи не могут точно назвать метраж квартиры. Эти данные необходимы нам для исследования. Однако, данные не позволяют пока что ничем эти пропуски заполнить. Оставляем.
# * **kitchen_area**: 2278 пропусков. Скорее всего, пользователи не могут назвать точный метраж кухни. Заполнить данные пока что нечем. Оставляем.
# * **locality_name**: 49 пропусков. На исследование не повлияет, оставляем.
# * **airport_nearest, cityCenters_nearest, parks_nearest, ponds_nearest**: ~5000 пропусков. Из-за однородности ошибки, решил вынести эти столбцы в один пункт. Скорее всего ошибка вызвана отсутсвием данных с карт. Оставляем.
# * **parks_around3000, ponds_around3000**: количество пропусков в этих данных одинаково - 5518, что выглядит странно. Пока что оставляем.

# %% [markdown]
# **Заполняем пропуски по высоте потолков медианным значением, категоризируя высоту по населенным пунктам**

# %%
for locality in df['locality_name'].unique():
    df.loc[(df['locality_name'] == locality) & (df['ceiling_height'].isna()), 'ceiling_height'] = \
    df.loc[(df['locality_name'] == locality), 'ceiling_height'].median()
df
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20    13000000      108.00           2019-03-07      3
# 1                 7     3350000       40.40           2018-12-04      1
# 2                10     5196000       56.00           2015-08-20      2
# 3                 0    64900000      159.00           2015-07-24      3
# 4                 2    10000000      100.00           2018-06-19      2
# ...             ...         ...         ...                  ...    ...
# 23694             9     9700000      133.81           2017-03-21      3
# 23695            14     3100000       59.00           2018-01-15      3
# 23696            18     2500000       56.70           2018-02-11      2
# 23697            13    11475000       76.75           2017-03-28      2
# 23698             4     1350000       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит исключить предупреждения. Иногда их бывает слишком много, поэтому важно уметь их скрывать. В этом тебе поможет библиотека warnings. Попробуй найти подходящий метод и убрать предупреждения.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />При заполнении средним или медианой необходимо четко отслеживать изменение других статистик: стандартное отклонение, дисперсию и другие параметры выборки
#
# ... если рассмотреть районность высоты потолков, т.к. в современных районах Питера высота потолков будет ожидаема ниже, чем в исторических, мы увидим, что заполнение подобного объема пропусков медианой или средним значением «размажет» это отличительное свойство объектов недвижимости в центре Питера
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)

# %%
df.loc[df['ceiling_height'] >= 5, 'ceiling_height'].count()
# Out:
# 41

# %%
df.loc[df['ceiling_height'] >= 20, 'ceiling_height'] = df['ceiling_height'] / 10

# %% [markdown]
# **Построим гистограмму и график размаха**

# %%
df['ceiling_height'].sort_values().plot(y='ceiling_height', kind='hist', bins=30);

# %%
df.boxplot(column='ceiling_height', figsize=(10, 15))
plt.ylim(1, 6)
# Out:
# (1.0, 6.0)

# %% [markdown]
# **Из графика размаха видно, что высоты меньше 2,5м и больше 2,9 метров являются выбросами. Округлим верхний порог до 3 и исключим значения из наших данных**

# %%
df[df['locality_name'] == 'Санкт-Петербург']['ceiling_height'].plot(y='ceiling_height', kind='hist', bins=30, figsize=(10, 8));

# %%
percentage = '{:.1%}'.format((len(df[df['ceiling_height'] < 2]) + len(df[df['ceiling_height'] > 4])) \
      / len(df['ceiling_height']))

print(percentage)
# Out:
# 0.2%

# %%
df = df.query('2 <= ceiling_height <= 4 or ceiling_height.isna()')

# %%
# check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23554 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23554 non-null  int64
#  1   last_price            23554 non-null  int64
#  2   total_area            23554 non-null  float64
#  3   first_day_exposition  23554 non-null  datetime64[ns]
#  4   rooms                 23554 non-null  int64
#  5   ceiling_height        23400 non-null  float64
#  6   floors_total          23554 non-null  int64
#  7   living_area           21690 non-null  float64
#  8   floor                 23554 non-null  int64
#  9   is_apartment          23554 non-null  bool
#  10  studio                23554 non-null  bool
#  11  open_plan             23554 non-null  bool
#  12  kitchen_area          21332 non-null  float64
#  13  balcony               23554 non-null  int64
#  14  locality_name         23506 non-null  object
# ...

# %%
# check
df.locality_name.nunique()
# Out:
# 364

# %% [markdown]
# #### check

# %%
# df = df.query('2 <= ceiling_height <= 4')

# %%
# check
df.locality_name.nunique()
# Out:
# 364

# %%
# check
df.shape[0]
# Out:
# 23554

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#     df = df.query('2 <= ceiling_height <= 4')
#
# Так мы познакомились с особенностью фильтрации в библиотеке пандас, все NaN убегают вместе со значениями, которые не подходят под нашу фильтрацию, поэтому процент потери записей огромен
#
# Минус 150 записей
#
# стоит настроить условия фильтрации, чтобы не потерять записи с пропусками
#
# <b>алгоритм фильтрации столбца с пропусками: задаем основное условие фильтрации, + прибавляем условие не трогать записи с пропусками</b>
#
# стоит обратить внимание на весь код фильтрации, т.к. в нескольких колонках встречаются пропуски
#
#         плюс мы потеряли около 81 уникальных названий локаций, это не страшно, т.к. по видимому таких записей у нас по 1-2 штуки, по этой причине мы можем списать их на удаление редких значений ..., но отметить это в отчете стоит

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Добавил в условие фильтрации не трогать NaN записи

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Слишком жесткое условие для фильтрации выборки, особенно для Питера и его исторической части, стоит посмотреть на гистограмму параметра, чтобы определить, где начинаются редкие значения
#
#         df = df.query('2.5 <= ceiling_height <= 3')
#
# Если при фильтрации одной колонки, на этом проекте, теряем больше одного процента данных от изначального объема, стоит еще раз пересмотреть условия фильтрации

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Я последовал Вашему совету и, рассмотрев гистограмму по заданым значениям, пришел к выводу, что оптимальными значениями для фильтрации будут 2 и 4 метра, с учётом особенностей Санкт-Петербурга. Выше также проведет небольшой расчет, который указывает на то, что в результате фильтрации из датафрейма было убрано примерно 0.2% данных, что подходит под критерий "не более 1% данных".

# %% [markdown]
# #### Убираем явные и неявные дубликаты

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Явных дубликатов не найдено**

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Проверка на поиск дубликатов выполнена, молодец
#
# Особенно это станет важным, когда мы перейдем к более сложным задачам на втором модуле курса
#
# __Стоит выполнять повторный поиск после обработки неявных дубликатов__

# %%
df['locality_name'].sort_values().unique()
# Out:
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалёво',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'городской поселок Большая Ижора', 'городской поселок Янино-1',
#        'городской посёлок Будогощь', 'городской посёлок Виллози',
#        'городской посёлок Лесогорский', 'городской посёлок Мга',
#        'городской посёлок Назия', 'городской посёлок Новоселье',
#        'городской посёлок Павлово', 'городской посёлок Рощино',
# ...

# %% [markdown]
# **Из исследования уникальных названий населенных пунктов видно, что слова поселок/посёлок повторяют друг друга. Заменим эти значения**

# %%
df['locality_name'] = df['locality_name'].str.replace('поселок', 'посёлок')
df['locality_name'].sort_values().unique()
# Out:
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалёво',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'городской посёлок Большая Ижора', 'городской посёлок Будогощь',
#        'городской посёлок Виллози', 'городской посёлок Лесогорский',
#        'городской посёлок Мга', 'городской посёлок Назия',
#        'городской посёлок Новоселье', 'городской посёлок Павлово',
#        'городской посёлок Рощино', 'городской посёлок Свирьстрой',
# ...

# %% [markdown]
# **Также можно заметить, что названия некоторых населённых пунктов повторяются. Исправим это.**

# %%
# check
df.locality_name.nunique()
# Out:
# 330

# %%
df = df.replace({'locality_name': {
    'Никольское': 'посёлок городского типа Никольский',
    'Советский': 'посёлок городского типа Советский',
    'деревня Гарболово': 'посёлок Гарболово',
    'деревня Рабитицы': 'посёлок Рабитицы',
    'деревня Зимитицы': 'посёлок Зимитицы',
    'посёлок Рябово': 'посёлок городского типа Рябово',
    'посёлок станции Вещево': 'посёлок при железнодорожной станции Вещево',
    'посёлок станции Приветнинское': 'посёлок при железнодорожной станции Приветнинское',
    'городской посёлок Рощино': 'посёлок городского типа Рощино',
    'посёлок Громово': 'посёлок станции Громово',
    'Любань': 'посёлок Любань',
    'Кудрово': 'деревня Кудрово'
    
}})

# %%
# check
df.locality_name.nunique()
# Out:
# 319

# %%
# check
df.locality_name.unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'посёлок городского типа Красный Бор', 'Гатчина',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'посёлок Молодцово',
#        'посёлок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'посёлок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'посёлок Торковичи', 'посёлок Первомайское',
#        'Красное Село', 'посёлок Понтонный', 'Сясьстрой', 'деревня Старая',
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Хорошая работа по избавлению от неявных дубликатов
#
# Стоит доработать
#
#         'поселок городского типа мга',
#         'городской поселок мга'
#
# Можно отметить в отчете — стоит ли объединять нас. пункты
#
#         'деревня Кудрово'
#         'Кудрово'

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# + дополнительно — на рабочих проектах стоит искать дубликаты по сумме ключевых параметров (подмножеству), для примера:
#
#  + общ. площадь квартиры,
#  + этаж,
#  + общая этажность дома,
#  + расстояние до центра
#  + название населенного пункта
#  + кол-во комнат
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html?highlight=duplicat#pandas.DataFrame.duplicated
#
# https://www.codecamp.ru/blog/pandas-find-duplicates/

# %% [markdown]
# **Избавимся от всех записей, где город не указан.**

# %%
df = df.dropna(subset=['locality_name'])
df['locality_name'].isna().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height            120
# floors_total                0
# living_area              1859
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area             2213
# balcony                     0
# locality_name               0
# airports_nearest         5512
# cityCenters_nearest      5492
# parks_around3000         5491
# parks_nearest           15508
# ponds_around3000         5491
# ponds_nearest           14504
# days_exposition             0
# dtype: int64

# %% [markdown]
# **Везде, где было возможно, пропуски и дубликаты были устранены.**

# %% [markdown]
# **Конечный вывод по предобработке данных**:
#
# * Были изменены типы столбцов *first_day_exposition, days_exposition, balcony, last_price* на подходящие.
# * Были устранены явные пропуски в столбцах *is_apartment, days_exposition, balcony*.
# * Были устранены пропуски в столбце *ceiling_height*, путем замены пропусков на медиану относительно населенного пункта.
# * Были устранены аномальные данные в столбце *ceiling_height*, путем анализа гистограммы и графика размаха, с последующей фильтрацией данных.
# * В столбце *locality_name* были устранены неявные дубликаты и удалены записи с пропусками

# %% [markdown]
# #### check gap

# %%
# check
data = df.copy()

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23506 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23506 non-null  int64
#  1   last_price            23506 non-null  int64
#  2   total_area            23506 non-null  float64
#  3   first_day_exposition  23506 non-null  datetime64[ns]
#  4   rooms                 23506 non-null  int64
#  5   ceiling_height        23386 non-null  float64
#  6   floors_total          23506 non-null  int64
#  7   living_area           21647 non-null  float64
#  8   floor                 23506 non-null  int64
#  9   is_apartment          23506 non-null  bool
#  10  studio                23506 non-null  bool
#  11  open_plan             23506 non-null  bool
#  12  kitchen_area          21293 non-null  float64
#  13  balcony               23506 non-null  int64
#  14  locality_name         23506 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# стоит сменить тип данных в
#
#           6   floors_total          21846 non-null  float64
#
# пропуски можно удалить, кол-во их минимально

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Поправил данный столбец в блоке "предобработка данных"

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __проверим какие аномалии остались__ таблица ниже

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир
# сырые данные

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_3d973_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3d973_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_3d973_row0_col0" class="data row0 col0" >23,506.00</td>
#                         <td id="T_3d973_row0_col1" class="data row0 col1" >23,506.00</td>
# ...

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости (в т.ч. и хвосты) в колонках:
#
#         'rooms', 'total_area',  'days_exposition', 'last_price', 'living_area',  'kitchen_area', 'floors_total'
#
# стоит обратить внимание на минимальные и максимальные значения в выборке и учесть наличие пропусков при фильтрации данных

# %%
df['rooms'].hist(bins=30, figsize=(15, 7));
df['rooms'].describe()
df['rooms'].value_counts()
# Out:
# 1     7991
# 2     7885
# 3     5761
# 4     1169
# 5      318
# 0      193
# 6      101
# 7       57
# 8       12
# 9        8
# 10       3
# 11       2
# 14       2
# 19       1
# 16       1
# 12       1
# 15       1
# Name: rooms, dtype: int64

# %%
percentage = '{:.1%}'.format((len(df[df['rooms'] < 1]) + len(df[df['rooms'] > 7])) \
      / len(df['rooms']))
percentage
# Out:
# '1.0%'

# %%
df = df.query('1 <= rooms <= 7')

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Убираем редкие значения столбца rooms, потери данных составляют 1%. В 1% укладываемся

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Скажи пожалуйста, по какой причине мы оставляем записи с кол-ом комнат менее 7-ми

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Вероятно, вы хотели сказать "больше 7". Поправил условия фильтрации.

# %% [markdown]
# <div style>
# <font size="4"><b></b></font>
# <font size="5", color = "black">
# 😉

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Да, сорри, ты прав :)

# %%
df['total_area'].hist(bins=50, figsize=(15, 7));
df['total_area'].describe()
# Out:
# count    23282.000000
# mean        60.083233
# std         33.469806
# min         12.000000
# 25%         40.100000
# 50%         52.000000
# 75%         69.700000
# max        631.200000
# Name: total_area, dtype: float64

# %%
percentage = '{:.1%}'.format((len(df[df['total_area'] < 12]) + len(df[df['total_area'] > 250])) \
      / len(df['total_area']))
percentage
# Out:
# '0.4%'

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Терям 1% данных, укладываемся

# %%
df = df.query('total_area >= 12 and total_area <= 250')

# %%
# df['days_exposition'].hist(bins=50, figsize=(15, 7));
df['days_exposition'].describe()
df['days_exposition'].hist(bins=50, range=(0, 5), figsize=(15, 7));

# %%
percentage = '{:.1%}'.format((len(df.query('0 < days_exposition < 3')) + len(df[df['days_exposition'] > 1200])) \
      / len(df['days_exposition']))
percentage
# Out:
# '0.4%'

# %%
df = df.query('days_exposition == 0 or 3 <= days_exposition <= 1200')

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#         Редкие значения начинаются со значения 800.
#
# Выборка data['days_exposition'] имеет длинный правый хвост, не стоит обрезать подобный хвост на таких значениях, оптимально ориентироваться на значения 0,99 квантиля, это где-то 1200 дней ...
#
# Мы сначала заполнили пропуски нулями, а затем удалили
#
#         минус 3000 записей
#
# стоит вернуть

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Убираем редкие значения в 1 и 2 дня, также избавляемся от редких значений, которые идут после 0.99 квантиля. Итого теряем 0.4% данных.

# %%
ax = df['last_price'].hist(bins=100, figsize=(15, 7));
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{x/1000000:.1f} млн'))
plt.xlabel('Last Price')
df['last_price'].describe()
# Out:
# count    2.310500e+04
# mean     6.167518e+06
# std      6.923998e+06
# min      1.219000e+04
# 25%      3.450000e+06
# 50%      4.630000e+06
# 75%      6.700000e+06
# max      3.300000e+08
# Name: last_price, dtype: float64

# %%
percentage = '{:.1%}'.format((len(df[df['last_price'] < 500000]) + len(df[df['last_price'] > 30000000])) \
      / len(df['last_price']))
percentage
# Out:
# '1.0%'

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Редкие значения начинаются примерно с 30 млн рублей. Если уберем, то потеря составит 0.8%. Убираем аномалии.

# %%
df = df.query('last_price >= 500000 and last_price <= 30000000')

# %%
df['living_area'].hist(bins=30, figsize=(15, 7));
df['living_area'].describe()
# Out:
# count    21071.000000
# mean        33.190497
# std         17.497932
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.000000
# max        180.000000
# Name: living_area, dtype: float64

# %%
percentage = '{:.1%}'.format((len(df[df['living_area'] < 10]) + len(df[df['living_area'] > 130])) \
      / len(df['living_area']))
percentage
# Out:
# '0.3%'

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Редкие значения начинаются примерно со 100 кв.м. Если уберем, то потеря составит 0.7%. Убираем аномалии.

# %% [markdown]
# #### check nan

# %%
# check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22869 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          22869 non-null  int64
#  1   last_price            22869 non-null  int64
#  2   total_area            22869 non-null  float64
#  3   first_day_exposition  22869 non-null  datetime64[ns]
#  4   rooms                 22869 non-null  int64
#  5   ceiling_height        22757 non-null  float64
#  6   floors_total          22869 non-null  int64
#  7   living_area           21071 non-null  float64
#  8   floor                 22869 non-null  int64
#  9   is_apartment          22869 non-null  bool
#  10  studio                22869 non-null  bool
#  11  open_plan             22869 non-null  bool
#  12  kitchen_area          20895 non-null  float64
#  13  balcony               22869 non-null  int64
#  14  locality_name         22869 non-null  object
# ...

# %%
df = df.query('living_area >= 10 and living_area <= 150 or living_area.isna()')
df['living_area'].hist(bins=50, figsize=(10, 8));

# %%
# check
df.shape[0]
# Out:
# 22825

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#     df = df.query('living_area >= 10 and living_area <= 100')
#
#
# Минус 1 600 записей
#
# стоит настроить условия фильтрации, чтобы не потерять записи с пропусками
#
# <b>алгоритм фильтрации столбца с пропусками: задаем основное условие фильтрации, + прибавляем условие не трогать записи с пропусками</b>
#
# стоит обратить внимание на весь код фильтрации, т.к. в нескольких колонках встречаются пропуски

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#      living_area <= 100
#
# Слишком жесткое условие для фильтрации выборки, особенно для Питера и его исторической части, стоит посмотреть на гистограмму параметра, чтобы определить, где начинаются редкие значения
#
# Если при фильтрации одной колонки, на этом проекте, теряем больше одного процента данных от изначального объема, стоит еще раз пересмотреть условия фильтрации

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Исправил условия фильтрации

# %%
df['kitchen_area'].hist(bins=30, figsize=(15, 7));
df['kitchen_area'].describe()
# Out:
# count    20853.000000
# mean        10.260415
# std          5.034351
# min          1.300000
# 25%          7.000000
# 50%          9.000000
# 75%         11.740000
# max         70.000000
# Name: kitchen_area, dtype: float64

# %%
percentage = '{:.1%}'.format((len(df[df['kitchen_area'] < 5]) + len(df[df['kitchen_area'] > 45])) \
      / len(df['kitchen_area']))
percentage
# Out:
# '0.6%'

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Редкие значения начинаются примерно со 40 кв.м. Если уберем, то потеря составит 0.8%. Убираем аномалии.

# %%
df = df.query('kitchen_area >= 5 and kitchen_area <= 40 or kitchen_area.isna()')

# %%
df['floors_total'].hist(bins=30, figsize=(15, 7));
print(df['floors_total'].describe())
df['floors_total'].value_counts()
# Out:
# count    22652.000000
# mean        10.707664
# std          6.586463
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64
# 5     5591
# 9     3697
# 16    1338
# 12    1336
# 10    1152
# 4     1128
# 25    1036
# 6      816
# 17     807
# 3      623
# 14     534
# 7      531
# 18     488
# 24     445
# 2      356
# 15     354
# 23     334
# 19     322
# 8      321
# 22     279
# 20     254
# 13     219
# 11     188
# 27     160
# 21     150
# 26     120
# 1       22
# 35      22
# 28      21
# 36       3
# 34       1
# 60       1
# 52       1
# 29       1
# 33       1
# Name: floors_total, dtype: int64

# %%
percentage = '{:.1%}'.format((len(df[df['floors_total'] < 2]) + len(df[df['floors_total'] > 28])) \
      / len(df['floors_total']))
percentage
# Out:
# '0.2%'

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Редкие значения начинаются примерно с 28-этажных домов. Если уберем, то потеря составит 0.2%. Убираем редкие значения.

# %%
df = df.query('floors_total >= 2 and floors_total <= 28')
df
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20    13000000      108.00           2019-03-07      3
# 1                 7     3350000       40.40           2018-12-04      1
# 2                10     5196000       56.00           2015-08-20      2
# 5                10     2890000       30.40           2018-09-10      1
# 6                 6     3700000       37.30           2017-11-02      1
# ...             ...         ...         ...                  ...    ...
# 23694             9     9700000      133.81           2017-03-21      3
# 23695            14     3100000       59.00           2018-01-15      3
# 23696            18     2500000       56.70           2018-02-11      2
# 23697            13    11475000       76.75           2017-03-28      2
# 23698             4     1350000       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Выше мной были удалены все аномалии, которые можно было убрать без значительной потери данных. Итоговая потеря составила 4.6%. Мы уложились в 5% желательного лимита.

# %%
loss_percentage = '{:.1%}'.format((records_count - df.shape[0]) / records_count)
loss_percentage
# Out:
# '4.6%'

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Отлично, молодец

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Потери составили
#
#         1 - 17447 / 23699 = 26,4%

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир
# сырые данные

(
    df[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_043ee_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_043ee_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_043ee_row0_col0" class="data row0 col0" >22,600.00</td>
#                         <td id="T_043ee_row0_col1" class="data row0 col1" >22,600.00</td>
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Ювелирная работа, молодец

# %%
# check
df.hist(column = 'days_exposition', bins = 50, figsize = (15,3), range = (0,5));

df.hist(column = 'days_exposition', bins = 50, figsize = (15,3), range = (0,5))
plt.ylim(0, 40);

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались редкости в  скорости продаж: один или два дня

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Доп. задание, на твое усмотрение — сможешь добавить в таблицу расчет медианного значения?
#
#         (
#             data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
#                   'floor', 'floors_total']]
#             .apply (['count', 'min', 'max'])
#             .style.format("{:,.2f}")
#         )

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для выполнения пункта 2.4. существует два подхода
#
# Можно механически бороться с выбросами, ...
#
# основная проблема такого подхода — не учитывается неоднородность нашей выборки: у нас здесь и малые поселки, и вторая столица страны, и исторический фонд и массовая застройка, и однушки и довольно большое кол-во многокомнатных квартир, или наоборот одна две квартиры с количеством комнат больше 7-ми ...
#
#
#
# если бы у нас в таблице были бы только однокомнатные квартиры из определенного района массовой застройки, тогда да, мы бы боролись с выбросами традиционными способами, при нашем многообразии населенных пунктов, многокомнатности такие подходы не работают... т.е. они работают, но это усложнит наш проект — придется разбить и объединить записи нашей таблицы по нескольким параметрам (кол-во комнат, район, и т.д.), а затем только выполнять все остальные пункты на каждой отдельной выборке
#
# Остается другой подход — убираем редкие значения и следим за количеством потерь...
#
# Для выборки из 23-х тысяч значений, несколько записей со стоимостью квадратного метра выше 1-го млн. руб., довольно редкое явление
#
# Хороший пример, высота потолков, которую мы отрезаем по нижней и верхней планке, это скорее аномальные записи, посмотрим на другой аспект — на редкости: кол-во комнат
#
# __т.е. мы не говорим о том, что квартир с кол-ом комнат выше 7 не бывает, мы говорим, что для нашего исследования это редкие выбивающиеся из общей картины уникальные объекты, по которым необходимо проводить отдельную работу ...__
#
# подобным образом рассматриваем и остальные параметры
#
# наши помощники
#
# 1. гистограммы, с хорошим масштабом
# 2. метод describe() или облегченная версия, пример выше
# 3. метод value_counts()
#
# плюс жизненный опыт

# %%
# check

try:
    df_check = pd.read_csv('https://code.s3.yandex.net/datasets/real_estate_data.csv', sep='\t')
# если не получилось прочитать файл из локальной папки, то загружаем данные из сети
except:
    df_check = pd.read_csv('real_estate_data.csv', sep='\t')

# %%
# check
df_check.rooms.value_counts().to_frame()
# Out:
#     rooms
# 1    8047
# 2    7940
# 3    5814
# 4    1180
# 5     326
# 0     197
# 6     105
# 7      59
# 8      12
# 9       8
# 10      3
# 11      2
# 14      2
# 19      1
# 16      1
# 12      1
# 15      1

# %%
# check
df_check.total_area.hist(bins = 150, figsize = (15,3));

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />т.е. все квартиры менее 20-ти и более 250-ти квадратных метров можно считать редкостями

# %%
# check
df_check.total_area.hist(bins = 150, figsize = (15,3), range = (180,500));

# %%
# check
df_check.total_area.hist(bins = 15, figsize = (15,3), range = (180,500));

# %%
# check
df_check.total_area.hist(bins = 15, figsize = (15,3), range = (0,25));

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Осталось завершить выполнение пункта 2.4 из брифа проекта
#
# 2.4.	Найдите и устраните редкие и выбивающиеся значения.
#
# __Критичный уровень потерь записей на этапе предобработки составляет 10%, оптимальный 5%__
#
# Если при фильтрации одной колонки, на этом проекте, теряем больше одного процента данных от изначального объема, стоит еще раз пересмотреть условия фильтрации

# %%
# check

# Значения параметров объектов недвижимости на разных квантилях

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  
        'kitchen_area', 'floor',   'floors_total']]
    .quantile([0.0012, 0.01, .5, .99, .9988]) # выбираем размах в 0,9976 квантилей 
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_bcf31_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bcf31_level0_row0" class="row_heading level0 row0" >0.0012</th>
#                         <td id="T_bcf31_row0_col0" class="data row0 col0" >0.00</td>
#                         <td id="T_bcf31_row0_col1" class="data row0 col1" >20.00</td>
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Квантили что это такое (первая ссылка иногда не открывается)
#
# https://fin-accounting.ru/cfa/l1/quantitative/cfa-quartiles-quintiles-deciles-percentiles?ysclid=l7gy2kky4i156375632
#
# https://www.codecamp.ru/blog/percentile-vs-quartile-vs-quantile/?ysclid=lg89wjm4zz267333250
#
# они помогают увидеть редкости и аномалии в данных

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %%
df['price_one_square'] = (df['last_price'] / df['total_area']).round(2)

# %%
df['exposition_weekday'] = df['first_day_exposition'].dt.weekday
df['exposition_month'] = df['first_day_exposition'].dt.month
df['exposition_year'] = df['first_day_exposition'].dt.year

# %%
def get_floor_name(row):
    floor = row['floor']
    floors_total = row['floors_total']
    if floor == 1:
        return 'первый'
    elif floor == floors_total:
        return 'последний'
    elif floor <= 0:
        return 'ошибка'
    else:
        return 'другой'

# %%
df['floor_name'] = df.apply(get_floor_name, axis=1)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Функция хорошая, стоит учесть крайние условия: нулевые и отрицательные значения

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Поправил функцию, теперь если значение неккоректно, в поле будет формироваться строка "ошибка"

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />принимается
#
#         а если floors_total будет меньше нуля, тогда ?

# %%
df['cityCenters_nearest_km'] = round(df['cityCenters_nearest'] / 1000)

# %%
df.head(5)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 5            10     2890000        30.4           2018-09-10      1
# 6             6     3700000        37.3           2017-11-02      1
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0           2.700            16         51.0      8         False  ...
# 1           2.615            11         18.6      1         False  ...
# 2           2.700             5         34.3      4         False  ...
# 5           2.600            12         14.4      5         False  ...
# 6           2.640            26         10.6      6         False  ...
#
#    parks_nearest  ponds_around3000  ponds_nearest  days_exposition  \
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> данные добавлены корректно, молодец

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# #### Общая жилая площадь

# %%
ax = df.plot(y='total_area', grid=True, figsize=(10, 8), kind='hist', bins=30, range=(0, 200), title='График частоты встречаемости жилой площади')
ax.set_xlabel(r'Общая площадь объекта ($м^{2}$)')
ax.set_ylabel('Частота')
print(df['total_area'].describe())
# Out:
# count    22600.000000
# mean        57.721441
# std         25.526678
# min         12.000000
# 25%         40.000000
# 50%         51.700000
# 75%         68.000000
# max        250.000000
# Name: total_area, dtype: float64

# %% [markdown]
# **Распределение данных в целом нормальное. Присутствуют небольшие выбросы, но на мой взгляд, они не являются критичными. В основном, превалируют квартиры с метражом от 30 до 65$м^2$**.

# %% [markdown]
# #### Жилая площадь

# %%
ax = df.plot(y='living_area', grid=True, figsize=(10, 8), kind='hist', bins=30, range=(0, 200), title='График частоты встречаемости жилой площади')
ax.set_xlabel(r'Жилая площадь ($м^{2}$)')
ax.set_ylabel('Частота')
print(df['living_area'].describe())
plt.show()
# Out:
# count    20815.000000
# mean        33.057751
# std         16.951372
# min         10.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.000000
# max        150.000000
# Name: living_area, dtype: float64

# %% [markdown]
# **Распределение данных в целом удовлетворительное, однако, имеются "хвосты" из-за редких больших значений. Большая часть объектов имеет жилую площадь от 15 до 30$м^2$. Объекты с жилой площадью больше 55$м^2$ встречаются уже реже.**

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Хорошие графики, можно добавить кол-во корзин к параметрам гистограммы
#
# Подписи осей на графиках и название добавят ясности и читабельности.
# Это важные элементы любой визуализации. Как добавить подписи и названия, смотри [здесь](https://proproprogs.ru/modules/matplotlib-razmeshchaem-standartnye-tekstovye-elementy-na-grafike?ysclid=l6agtioc6f299002507)

# %% [markdown]
# #### Площадь кухни

# %%
ax = df.plot(y='kitchen_area', grid=True, figsize=(10, 8), kind='hist', bins=30, range=(0, 80), title='График частоты встречаемости площади кухни')
ax.set_xlabel(r'Площадь кухни ($м^{2}$)')
ax.set_ylabel('Частота')
print(df['kitchen_area'].describe())
plt.show()
# Out:
# count    20635.000000
# mean        10.158519
# std          4.528350
# min          5.000000
# 25%          7.000000
# 50%          9.000000
# 75%         11.700000
# max         40.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# **Распределение данных нормальное. Примерная площадь кухни составляет от 5 до 15$м^2$. Кухни с большей площадью встречаются реже. Наблюдается небольшой хвост на графике из-за редких больших значений.**

# %% [markdown]
# #### Цена объекта

# %%
ax = df.plot(y='last_price', grid=True, figsize=(10, 8), kind='hist', bins=30, range=(0, 30700000), title='График частоты встречаемости цены')
ax.set_xlabel('Цена (млн. руб.)')
ax.set_ylabel('Частота')
print(df['last_price'].describe())
# Out:
# count    2.260000e+04
# mean     5.675504e+06
# std      3.866878e+06
# min      5.000000e+05
# 25%      3.434750e+06
# 50%      4.600000e+06
# 75%      6.600000e+06
# max      3.000000e+07
# Name: last_price, dtype: float64

# %% [markdown]
# **Распределение данные нормальное. Большинство объектов имеют ценовой диапазон от 3 до 5 миллионов рублей. Вариантов больше или меньше этого диапазона немного. Наиболее частый вариант: 3.5 миллиона рублей.**

# %% [markdown]
# #### Количество комнат

# %%
ax = df.plot(y='rooms', grid=True, figsize=(10, 8), kind='hist', bins=50, range=(0, 30), title='График частоты встречаемости  различного кол-ва комнат')
ax.set_xlabel('Кол-во комнат')
ax.set_ylabel('Частота')
df['rooms'].describe()
# Out:
# count    22600.000000
# mean         2.041770
# std          0.976302
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          7.000000
# Name: rooms, dtype: float64

# %% [markdown]
# **Распределение данных нормальное. В основном преобладают квартиры с 1 до 3 комнат. Количество однушек может быть обусловлено тем, что на рынке много предложений квартир-студий.**

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Стоит изменить параметры отображения гистограммы (добавить корзин), сейчас трудно определить типовое кол-во комнат

# %% [markdown]
# #### Высота потолков

# %%
ax = df.plot(y='ceiling_height', grid=True, figsize=(10, 8), kind='hist', bins=30, range=(0, 10), title='График частоты встречаемости высоты потолков')
ax.set_xlabel('Высота потолков (м)')
ax.set_ylabel('Частота')
df['ceiling_height'].describe()
# Out:
# count    22491.000000
# mean         2.693507
# std          0.202274
# min          2.000000
# 25%          2.550000
# 50%          2.700000
# 75%          2.700000
# max          4.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# **После предварительной обработки данные о высоте потолков выглядят разумно, в рамках от 3 до 5 метров. Выбросов и аномальных значений и выбросов больше нет.**

# %% [markdown]
# #### Этаж квартиры

# %%
ax = df.plot(y='floor', grid=True, figsize=(10, 8), kind='hist', bins=50, range=(1, 40), title='График частоты встречаемости этажей')
ax.set_xlabel('Этаж')
ax.set_ylabel('Частота')
df['floor'].describe()
# Out:
# count    22600.000000
# mean         5.867655
# std          4.843071
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          8.000000
# max         27.000000
# Name: floor, dtype: float64

# %% [markdown]
# **Распределение данных нормальное. Больше всего преобладают частные дома, имеющие один этаж. Также весьма популярны пятиэтажки.**

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит изменить параметры отображения гистограммы (добавить корзин), сейчас трудно определить границу резкого снижения кол-ва объявлений, или на 1-ке, или на 5-ке, или на 6-ке ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит добавлять больше корзин

# %%
# check

ax = df.plot(y='floor', grid=True, 
             figsize=(10, 4), kind='hist', bins=54,  title='График частоты встречаемости этажей')
ax.set_xlabel('Этаж')
ax.set_ylabel('Частота');

# %% [markdown]
# #### Тип этажей квартиры

# %%
floor_count = len(df[df['floor_name'] == 'первый'])\
    + len(df[df['floor_name'] == 'последний']) \
    + len(df[df['floor_name'] == 'другой'])
floor_types = df.pivot_table(index='floor_name', values='floors_total', aggfunc=len)
floor_types['percentage'] = floor_types['floors_total'] / floor_count
floor_types['percentage'] = floor_types['percentage'].map('{:.1%}'.format)
floor_types.plot(kind='pie', y='floors_total', autopct='%.1f%%', figsize=(10, 8));

# %% [markdown]
# **По количествам предложений, меньше всего занимаю первые и последние этажи (12.2% и 13.5% соответственно). Больше всего (74%) на рынке именно "середнячковых" этажей. Вместо гистограммы я решил построить круговую диаграму, так как на мой взгляд она более наглядно показывает распределение этажей по категориям.**

# %% [markdown]
# #### Общее количество этажей

# %%
ax = df.plot(y='floors_total', grid=True, figsize=(10, 8), kind='hist', bins=100, range=(0, 30), title='График частоты встречаемости различных этажей')
ax.set_xlabel('Кол-во этажей')
ax.set_ylabel('Частота')
df['floors_total'].describe()
# Out:
# count    22600.000000
# mean        10.683274
# std          6.518114
# min          2.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         28.000000
# Name: floors_total, dtype: float64

# %% [markdown]
# **Распределение данных в целом удовлетворительное. Преобладают в основном пятиэтажки и девятиэтажки. В хвосте видно, что стали строить больше 25 этажек.**

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит изменить параметры отображения гистограммы (добавить корзин), сейчас  трудно определить типовую высотность зданий

# %% [markdown]
# #### Расстояние до центра города в метрах

# %%
ax = df.plot(y='cityCenters_nearest', grid=True, figsize=(10, 8), kind='hist', bins=30, title='График частоты встречаемости расстояния до центра')
ax.set_xlabel(r'Расстояние до центра города (м)')
ax.set_ylabel('Частота')
df['cityCenters_nearest'].describe()
# Out:
# count    17272.000000
# mean     14383.731704
# std       8569.659059
# min        208.000000
# 25%       9635.500000
# 50%      13220.000000
# 75%      16360.250000
# max      65968.000000
# Name: cityCenters_nearest, dtype: float64

# %% [markdown]
# **Из гистограммы видно, что больше всего распространены квартиры, которые находятся от центра города на расстоянии от 10000м (10км) до 20000м (20км). Дальше уже идут менее популярные пригороды.**

# %% [markdown]
# #### Расстояние до ближайшего аэропорта

# %%
ax = df.plot(y='airports_nearest', grid=True, figsize=(10, 8), kind='hist', bins=30, title='График частоты встречаемости расстояния до аэропорта')
ax.set_xlabel('Расстояние до аэропорта (м)')
ax.set_ylabel('Частота')
df['airports_nearest'].describe()
# Out:
# count    17252.000000
# mean     28879.190992
# std      12723.836328
# min          0.000000
# 25%      18446.000000
# 50%      26911.000000
# 75%      37412.000000
# max      84869.000000
# Name: airports_nearest, dtype: float64

# %% [markdown]
# **В целом, реальное распределение данных. Аэропорты в среднем расположены на расстоянии от 15000м (15км) до 40000м (40км).**

# %% [markdown]
# #### Расстояние до ближайшего парка

# %%
ax = df.plot(y='parks_nearest', grid=True, figsize=(10, 8), kind='hist', bins=30, title='График частоты встречаемости расстояния до парка')
ax.set_xlabel('Расстояние до парка (м)')
ax.set_ylabel('Частота')
df['parks_nearest'].describe()
# Out:
# count    7596.000000
# mean      492.927988
# std       340.083780
# min         1.000000
# 25%       289.000000
# 50%       456.000000
# 75%       614.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %% [markdown]
# **Нормальное распределение данных. Имеется хвост из-за редких, но больших значений. В целом, парки от квартир расположены на расстоянии от 100м до 1000м.**

# %% [markdown]
# #### День и месяц публикации объявления

# %% [markdown]
# ##### День публикации

# %%
ax = df.plot(y='exposition_weekday', grid=True, figsize=(10, 8), kind='hist', bins=30, title='График частоты публикации по дням')
ax.set_xlabel('Номер дня недели')
ax.set_ylabel('Частота')
df['exposition_weekday'].describe()
# Out:
# count    22600.000000
# mean         2.567699
# std          1.789938
# min          0.000000
# 25%          1.000000
# 50%          3.000000
# 75%          4.000000
# max          6.000000
# Name: exposition_weekday, dtype: float64

# %% [markdown]
# **Из гистограммы видно, что в основном объявления размещаются в рабочие дни. В выходные активность публикаций падает.**

# %% [markdown]
# ##### Месяц публикации

# %%
ax = df.plot(y='exposition_month', grid=True, figsize=(10, 8), kind='hist', bins=30, title='График частоты публикации по месяцам')
ax.set_xlabel('Номер месяца')
ax.set_ylabel('Частота')
df['exposition_month'].describe()
# Out:
# count    22600.000000
# mean         6.396549
# std          3.490216
# min          1.000000
# 25%          3.000000
# 50%          6.000000
# 75%         10.000000
# max         12.000000
# Name: exposition_month, dtype: float64

# %% [markdown]
# **Из гистограммы видно, что в основном объявления публикуют в период с февраля по апрель, после чего активность снижается. Начиная с сентября и заканчивая ноябрем, активность публикаций снова растёт.**

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️  Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Интересно, почему февраль (самый короткий месяц) опережает все месяцы — ?__

# %% [markdown]
# #### Изучение скорости продажи квартир

# %%
df['days_exposition'].describe()
# Out:
# count    22600.000000
# mean       151.530752
# std        200.141541
# min          0.000000
# 25%         23.000000
# 50%         73.000000
# 75%        195.000000
# max       1200.000000
# Name: days_exposition, dtype: float64

# %%
df['days_exposition'].plot(y='days_exposition', figsize=(10, 8), bins=150, range=(0, 100), kind='hist');

# %% [markdown]
# **Среднее 182, медиана около 100. В основном, квартиры продаются за 45, 60 и 90 дней. Возможно, на это влияет тот факт, что по умолчанию Яндекс.Недвижимость в зависимости от цены объекта, снимает объявления по истечению данных сроков. Видно, что межквартальный размах - от 23 до 193 дней. Скорее всего, в данном столбце присутствуют аномальные значения. Построим диаграмму размаха для данного столбца.**

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#         квартиры продаются за 45 и 60 дней.
#
# [Условия размещения объявлений](https://yandex.ru/support/realty/owner/home/add-ads-housing.html)

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />В расчете скорости продаж не исключены нулевые заглушки, более 3000 записей с нулевой скоростью продаж искажают среднее и медианное значения
#
# Стоит пересчитать статистики скорости продажи после восстановления пропусков

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Поправил итоговый вывод к данной гистограмме, исправил включение нулевых значений в блоке "предобработка данных"

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Пропуски в ['days_exposition'] говорят нам, что квартиры еще не проданы..., неверно терять столь важный признак, →
#
# не стоит удалять подобные записи из выборки, для расчета скорости продаж, временно исключаем их из расчета

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Поправил фильтрацию, теперь записи с пропусками присутсвуют в выборке

# %%
df.boxplot(column='days_exposition', figsize=(10, 8))
plt.ylim(-100, 600)
plt.show()

# %%
df['days_exposition'].quantile(.99).round(2)
# Out:
# 960.0

# %%
len(df[df['days_exposition'] > 960])
# Out:
# 224

# %% [markdown]
# **Значений достаточно много, что объясняет аномалии в диаграмме размаха. Удалим эти значения.*

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Выборка data['days_exposition'] имеет длинный правый хвост, не стоит обрезать подобный хвост на таких значениях, оптимально ориентироваться на значения 0,99 квантиля, это где-то 1200 дней ...
#
#         df_good_exp = df.query('days_exposition < 450')

# %%
df_good_exp = df.query('days_exposition < 960 and days_exposition != 0')
df_good_exp['days_exposition'].plot(y='days_exposition', kind='hist', figsize=(10, 8), bins=50);

# %%
print(df_good_exp['days_exposition'].describe())

print('25 quantile:', df_good_exp['days_exposition'].quantile(.25))
print('75 quantile:', df_good_exp['days_exposition'].quantile(.75))
# Out:
# count    19372.000000
# mean       164.304821
# std        182.167160
# min          3.000000
# 25%         44.000000
# 50%         92.000000
# 75%        218.000000
# max        959.000000
# Name: days_exposition, dtype: float64
# 25 quantile: 44.0
# 75 quantile: 218.0

# %% [markdown]
# **В итоге мы убрали из датафрейма 224 строки, которые являются выбросами и избавились от правого хвоста. В результате анализа данных, я пришел к выводу, что быстрая продажа - это та, которая случилась до 22 дней, нормальная продажа - та, которая случилась от 22 до 189 дней, долгая продажа - та, которая происходит дольше 189 дней. Среднее - 142, медиана - 71.**

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#         В результате анализа данных, я пришел к выводу, что быстрая продажа - это та, которая случилась до 22 дней, нормальная продажа - та, которая случилась от 22 до 189 дней, долгая продажа - та, которая происходит дольше 189 дней. Среднее - 142, медиана - 71.
#
#
#  Стоит поправить вывод, сейчас в выводе расчеты, искаженные нулями ..., реальные данные ⬇⬇⬇
#
#         mean       164.304821
#         25%         44.000000
#         50%         92.000000
#         75%        218.000000

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#
# __Интересно посмотреть на изменение средней  скорости продаж по годам__

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />   Для определения быстрых и долгих продаж оптимальнее ориентироваться на 25-тый и 75-тый квантили

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Поправил итоговый вывод, с ориентировкой на новую выборку и указанные квантили.

# %%
# check
# Моды на реальных данных
     
df_check['days_exposition'].value_counts().to_frame().head(20).plot(kind = 'barh', figsize = (15,6), rot = 0);

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Моды на реальных данных
#
#         Мода (Mo) представляет собой значение изучаемого признака, повторяющееся с наибольшей частотой, т.е. мода – значение признака, встречающееся чаще всего. Медианой (Me) называется значение признака, приходящееся на середину ранжированной (упорядоченной) совокупности, т.е. медиана – центральное значение вариационного ряда.
#
# Выделяются моды на 45 и 60 дней, а значения на 44 и 45 дней, явно имеет техническую причину снятия, из-за формата числа
#
# В нашем проекте — моды, из-за подозрения что это техническое снятие с продаж, могут искажать реальный расчет скорости продажи квартиры
#
# полностью из проекта удалять их не стоит, можно временно исключить из расчета скорости продаж

# %% [markdown]
# #### Какие факторы больше всего влияют на общую (полную) стоимость объекта?
# * общей площади;
# * жилой площади;
# * площади кухни;
# * количества комнат;
# * этажа, на котором расположена квартира (первый, последний, другой);
# * даты размещения (день недели, месяц, год).

# %% [markdown]
# ##### Изучение корреляции с площадью

# %% [markdown]
# **Вычислим коэффициент корреляции между данными параметрами.**

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Для красоты («продаваемости») всего проекта не стоит выходить за видимую ширину тетради юпитер ноутбука, коллеги ценят удобство прочтения кода. Широкие строки кода рекомендуется — делить <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a>. ⬇⬇⬇
#
# </div>

# %%
print('Total area corr:', round(df['last_price'].corr(df['total_area']), 2))
print('Living area corr:', round(df['last_price'].corr(df['living_area']), 2))
print('Kitchen area corr:', round(df['last_price'].corr(df['kitchen_area']), 2))
print('Rooms area corr:', round(df['last_price'].corr(df['rooms']), 2))

corr_matrix = df[['last_price', 'total_area', 'living_area', 'kitchen_area', \
                  'rooms']].corr()
display(corr_matrix)
# Out:
# Total area corr: 0.78
# Living area corr: 0.68
# Kitchen area corr: 0.6
# Rooms area corr: 0.5
#               last_price  total_area  living_area  kitchen_area     rooms
# last_price      1.000000    0.782575     0.676408      0.598225  0.501112
# total_area      0.782575    1.000000     0.927920      0.549384  0.794894
# living_area     0.676408    0.927920     1.000000      0.321826  0.883770
# kitchen_area    0.598225    0.549384     0.321826      1.000000  0.185653
# rooms           0.501112    0.794894     0.883770      0.185653  1.000000

# %% [markdown]
# **Корреляции, которая бы стремилась к единице, среди этих параметров не замечено. Самое большое влияние на стоимость объекта пока что оказывает полная площадь квартиры. Построим диаграмму рассеяния для наглядности.**

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Коэффициент корреляции рассчитывается для всех зависимостей из задания, исключая параметры - день недели и месяц — это не эффективно, т.к. это нелинейные параметры
#
# чтобы они стали линейными, январь месяц 2015 года должен стать третьим и т.д., т.е. мы должны сделать перекодировку ...

# %%
df.plot(x='last_price', y='total_area', kind='scatter', figsize=(10, 8), alpha=0.5);

# %%
df.plot(x='last_price', y='living_area', kind='scatter', figsize=(10, 8), alpha=0.5);

# %%
df.plot(x='last_price', y='kitchen_area', kind='scatter', figsize=(10, 8), alpha=0.5);

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />  Можно попробовать настроить вид точечных графиков
#
# [Как сделать диаграмму рассеяния из фрейма данных Pandas](https://www.codecamp.ru/blog/pandas-scatter-plot/?ysclid=lh0tbpkoa9628147030)
#
# Примеры расчета коэф. корреляции и не только
#
# [Исследуем отношение между переменными](https://dfedorov.spb.ru/pandas/downey/%D0%98%D1%81%D1%81%D0%BB%D0%B5%D0%B4%D1%83%D0%B5%D0%BC%20%D0%BE%D1%82%D0%BD%D0%BE%D1%88%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BC%D0%B5%D0%B6%D0%B4%D1%83%20%D0%BF%D0%B5%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8.html?ysclid=l9ev0utyg728177057)

# %% [markdown]
# ##### Зависимость цены объекта от этажа

# %% [markdown]
# **Проверим зависимость стоимости объекта от этажа. Для этого построим сводную таблицу.**

# %%
floor_category = df.pivot_table(index='floor_name', values='last_price', aggfunc=['mean', 'count', 'median'])
floor_category.columns = ['mean', 'count', 'median']
floor_category.plot(y='median', figsize=(10, 8))
floor_category
# Out:
#                     mean  count   median
# floor_name
# другой      5.918941e+06  16649  4800000
# первый      4.537104e+06   2798  3900000
# последний   5.400297e+06   3153  4250000

# %% [markdown]
# **Из графика видно, что если квартира на первом этаже, то она будет гораздо дешевле, чем те, которые находятся выше. Исходя из этого, мы можем предполжить, что этаж расположения квартиры также влияет на общую стоимость объекта.**

# %% [markdown]
# ##### Зависимость цены объекта от дня недели размещения

# %%
weekday_exposition = df.pivot_table(index='exposition_weekday', values='last_price', aggfunc=['mean', 'count', 'median'])
weekday_exposition.columns = ['mean', 'count', 'median']
weekday_exposition.plot(y='median', figsize=(10, 8))
weekday_exposition.plot(y='median', figsize=(10, 8), ylim=(0, 5000000))
weekday_exposition
# Out:
#                             mean  count   median
# exposition_weekday
# 0                   5.708609e+06   3452  4600000
# 1                   5.693154e+06   4001  4700000
# 2                   5.801662e+06   3784  4675000
# 3                   5.767057e+06   4073  4600000
# 4                   5.603870e+06   3826  4550000
# 5                   5.463666e+06   1846  4500000
# 6                   5.446797e+06   1618  4500000

# %% [markdown]
# **Сперва мне показалось, что все же какая-то зависимость есть, однако, увеличив масштаб графика, стало видно, что никакого влияния на ценообразование день продажи не имеет.**

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Разница в 100 тыс. руб., у кого-то это зарплата, и может не за один месяц :)
#
# __Интересно по какой причине у нас так радикально меняется картина с подачей объявлений в выходные дни, падает кол-во и средняя стоимость или медианная?__

# %% [markdown]
# ##### Зависимость цены объекта от месяца размещения

# %%
month_exposition = df.pivot_table(index='exposition_month', values='last_price', aggfunc=['mean', 'count', 'median'])
month_exposition.columns = ['mean', 'count', 'median']
month_exposition.plot(y='median', figsize=(10, 8))
month_exposition.plot(y='median', figsize=(10, 8), ylim=(0, 5000000))
month_exposition
# Out:
#                           mean  count   median
# exposition_month
# 1                 5.731555e+06   1424  4600000
# 2                 5.710905e+06   2529  4630000
# 3                 5.611856e+06   2476  4605000
# 4                 5.716592e+06   2265  4754940
# 5                 5.590712e+06   1208  4500000
# 6                 5.446561e+06   1691  4370000
# 7                 5.668322e+06   1602  4600000
# 8                 5.700462e+06   1665  4550000
# 9                 5.819477e+06   1889  4680000
# 10                5.597074e+06   2041  4550000
# 11                5.763444e+06   2259  4650000
# 12                5.703980e+06   1551  4650000

# %% [markdown]
# **Та же самая ситуация, что и с днем недели. На масштабном графике видно, что месяц также не оказывает никакого влияния на ценообразование.**

# %% [markdown]
# ##### Зависимость цены объекта от года размещения

# %%
year_exposition = df.pivot_table(index='exposition_year', values='last_price', aggfunc=['mean', 'count', 'median'])
year_exposition.columns = ['mean', 'count', 'median']
year_exposition.plot(y='median', figsize=(10, 8))
year_exposition.plot(y='median', figsize=(10, 8), ylim=(0, 5000000))
year_exposition
# Out:
#                          mean  count   median
# exposition_year
# 2014             8.973532e+06    105  6500000
# 2015             6.407025e+06   1041  5100000
# 2016             5.653691e+06   2646  4495000
# 2017             5.614897e+06   7832  4500000
# 2018             5.496719e+06   8206  4550000
# 2019             5.997417e+06   2770  5000000

# %%
year_pivot_table = df.pivot_table(index='exposition_year', values=['last_price', 'total_area'], \
                                  aggfunc={'last_price': ['count', 'mean'], 'total_area': ['mean']}).round(2)
year_pivot_table.columns = ['count', 'mean', 'square_mean']
year_pivot_table['count'] = year_pivot_table['count'].astype('int')
display(year_pivot_table)
year_pivot_table.plot(y='count', figsize=(10, 8), ylabel='Количество объявлений', \
                      title='Зависимость количества объявлений от года');
year_pivot_table.plot(y='mean', figsize=(10, 8), ylabel='Средняя стоимость объекта', \
                      title='Зависимость средней стоимости объекта от года');
year_pivot_table.plot(y='square_mean', figsize=(10, 8), ylabel='Средняя площадь объекта', \
                      title='Зависимость средней площади объекта от года');
# Out:
#                  count        mean  square_mean
# exposition_year
# 2014               105  8973531.58        77.89
# 2015              1041  6407024.88        64.85
# 2016              2646  5653691.35        59.04
# 2017              7832  5614897.15        57.98
# 2018              8206  5496718.79        56.24
# 2019              2770  5997417.32        56.70

# %% [markdown]
# **Здесь масштаб никак не влияет на восприятие коррелляции. Видно, что после 2014 года цены начали резко снижаться на фоне роста числа объявлений. Возможно, сказалась общая финансовая неопределённость и кризис в стране. Однако, затем ситуация начала выправляться и из-за большей конкуренции, цены начали регулироваться и снижаться. К 2017 году на платформе уже было размещено 6800 объявлений, со средней стоимостью в 5.4 миллиона рублей. Также, на протяжении лет менялась и средняя площадь каждого объявления. Если в 2014 году, средняя площадь составляла 75.94$м^{2}$, то со временем средняя площадь устаканилась на 55$м^{2}$. Предполагаю, что после 2014 года сервис стал набирать популярность, из-за чего на площадке стало появляться больше объявлений и меняться ценообразование из-за большей конкуренции. Однако, даже когда количество объявлений к 2019 году начало снижаться, ценообразование и средняя площадь остались примерно на том же уровне. Так что я предполагаю, что год размещения объявления также никак напрямую не влияет на ценообразование.**

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит дополнить  вывод об изменении цен по годам, необходимо учесть другие факторы, которые также изменяются с годами: площадь и кол-во объявлений о продаже (стоит добавить или графики, или сводные таблицы и исследовать взаимное влияние параметров: кол-во записей и изменение средней цены и средней площади в течение лет)
#
#         Видно, что после 2014 года цены начали резко снижаться. Возможно, сказалась общая финансовая неопределённость и кризис в стране.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Если смотреть только на изменение цены по годам мы можем сделать некорректный вывод, что цены падали, а на самом деле цена это параметр на который влияет несколько других факторов, по этой причине можно посмотреть на основные из них:
#
# + изменение кол-ва записей — принять решение о достаточности данных для анализа и сравнения (сравнивать 100 объявлений и 8000, а возможно, что они еще и из разных локаций, не совсем корректно)
# + изменение площади, как основного параметра от которого зависит стоимость квартиры, в 2017-2018 гг. на сервис или рынок ИТ-торговли недвижимостью пришел массовый продавец, и средние значения упали ..., а за ней и цена
# + изменение кол-ва поданных объявлений из разных локаций, т.к. есть питерские квартиры, а есть выборгские квартиры и стоят они по разному, и в разные годы могло быть больше квартир из определенной локации
# + полнота периода для анализа, 2014 и 2019 гг. неполные, а у нас есть сезонные колебания цен, например летнее снижение цен
# + изменение доли дорогих категорий в общей выборке (средние этажи)
#
# и т.д.

# %% [markdown]
# **Вывод**:
# **В результате анализа данных, я пришёл к выводу, что на полную стоимость объекта влияет общая площадь объекта (коэффициент корреляции 0.64) и расположение квартиры на этаже. Первый этаж оказался самым дешёвым, а все, что оказалось выше оказалось дороже. В результате исследования зависимости цены объекта от даты (день, месяц и год), я пришел к выводу, что ни один из этих параметров напрямую не влияет на среднюю цену объекта. Количество объявлений за 2015 год резко увеличилось, цены снизились, однако в дальнейшем мы можем наблюдать, что ценообразование остается на одном и том же уровне, не смотря на рост количества объявлений. Ровно тоже самое можно сказать и о средней площади объекта.**

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Стоит добавить недостающие графики из 8-ми ⬇⬇⬇
#
# Шаг 4. Проведите исследовательский анализ данных:
#
# 3.	Какие факторы больше всего влияют на общую (полную) стоимость объекта?
#     Изучите, зависит ли цена от:
#     +	общей площади;
#     +	жилой площади;
#     +	площади кухни;
#     +	количества комнат;
#     +	этажа, на котором расположена квартира (первый, последний, другой);
#     +	даты размещения (день недели, месяц, год).
#
# Постройте графики, которые покажут зависимость цены от указанных выше параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы.
#
#
#
# Советы по графикам:
#
# + зависимость параметров (от площади, удалённости от центра) оптимальнее рассматривать на точечных графиках (тип scatter),
# + динамику на линейных (это про сравнение цен за год, месяц, день недели), — стоит сгруппировать значения и рассчитать среднее или медианное значение
# + сравнение цен на барах (для сравнение средней стоимости квартиры по трем категориям), — стоит сгруппировать значения и рассчитать среднее или медианное значение

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Поправил оба итоговых вывода, добавил расчеты и недостающие графики для корректного анализа зависимости от года. На мой взгляд, год в напрямую никак не влияет на ценообразование, хотя это и можно притянуть по косвенным признакам.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Стоит добавить недостающие 2 графика
#
#
#     +	жилой площади;
#     +	площади кухни;

# %% [markdown]
# #### Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра.

# %%
locality_table = df.pivot_table(index='locality_name', values='price_one_square', aggfunc=['count', 'mean'])
locality_table.columns = ['count', 'mean']
locality_table = locality_table.sort_values(by='count', ascending=False).head(10)
locality_table = locality_table.round(2)
locality_table
# Out:
#                    count       mean
# locality_name
# Санкт-Петербург    14906  110222.04
# посёлок Мурино       521   84911.27
# деревня Кудрово      448   95078.82
# посёлок Шушары       433   78264.19
# Всеволожск           390   68584.42
# Пушкин               355  102858.79
# Колпино              337   75333.30
# посёлок Парголово    321   90201.84
# Гатчина              302   68846.42
# Выборг               235   58140.85

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />ТОП-10 рассчитан корректно

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> на проектах стоит снижать размерность выводимой информации, где не требуется максимальная точность, до одного или двух знаков после запятой
#
#         Санкт-Петербург	14295	111841.232662
#         посёлок Мурино	556	85681.762572
#         деревня Кудрово	471	95326.179108

# %%
locality_table.sort_values(by='mean').plot(y='mean', kind='barh', figsize=(10, 8));

# %% [markdown]
# **В результате исследования данных, я сделал вывод, что самая большая стоимость квадратного метра в Санкт-Петербугре, а самая низкая в Выборге.**

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />    Можно развернуть график
#
#      kind='barh'
#
# [Постер поможет выбирать вид графиков](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)
#
# и отсортировать значения

# %% [markdown]
# #### Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города.

# %%
locality_km = df.query('locality_name == "Санкт-Петербург" and cityCenters_nearest_km > 0') \
                .pivot_table(index='cityCenters_nearest_km', values='last_price', aggfunc='mean').round(2)
locality_km.plot(figsize=(10, 8), marker='o')
locality_km
# Out:
#                          last_price
# cityCenters_nearest_km
# 1.0                     11630559.00
# 2.0                     10732872.09
# 3.0                      9702843.19
# 4.0                     10214541.97
# 5.0                     10683187.48
# 6.0                      9556568.02
# 7.0                      9237385.41
# 8.0                      8686308.69
# 9.0                      6733526.55
# 10.0                     6368709.20
# 11.0                     6018836.41
# 12.0                     5811798.65
# 13.0                     6073612.91
# 14.0                     5571863.41
# 15.0                     5700148.81
# 16.0                     5336625.93
# 17.0                     5244381.86
# 18.0                     4912160.76
# 19.0                     5096907.66
# 20.0                     4611578.95
# 21.0                     5484808.61
# 22.0                     5415524.28
# 23.0                     4741444.44
# 24.0                     3890686.80
# ...

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит поправить код
#
#         locality_km = df.query('locality_name == "Санкт-Петербург" and cityCenters_nearest_km > 0') \
#                         .pivot_table(index='cityCenters_nearest_km', values='last_price', aggfunc='mean')
#         locality_km.plot(figsize=(10, 8)
#         locality_km
#
# не хватает одной скобки

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит изучить записи, которые привели к провалу на 27-м км. или пику, если часть записей будет восстановлена
#
#
# ![image.png](attachment:image.png)

# %%
petersburg_km = df.query('locality_name == "Санкт-Петербург" and cityCenters_nearest_km == 27')

#city_km = df.pivot_table(index='cityCenters_nearest_km', values=['last_price', 'total_area', 'rooms'], \
#                         aggfunc={
#                                    'last_price': ['count', 'mean'],
#                                    'total_area': ['mean'],
#                                    'rooms': ['sum'],
#                         }).round(2)
#city_km
petersburg_km
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 748             13    14350000        74.0           2017-11-28      2
# 5961             6     2250000        32.0           2018-02-27      1
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 748             3.13             5         30.0      3         False  ...
# 5961            2.70             2         16.5      2         False  ...
#
#       parks_nearest  ponds_around3000  ponds_nearest  days_exposition  \
# 748          1496.0               0.0            NaN              128
# 5961            NaN               0.0            NaN              178
#
#      price_one_square  exposition_weekday  exposition_month  exposition_year  \
# 748         193918.92                   1                11             2017
# 5961         70312.50                   1                 2             2018
#
#       floor_name  cityCenters_nearest_km
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />расчет принимается, после восстановления записей у нас на графике выброс, а не провал ...
#
# ![image.png](attachment:image.png)
#
# у нас всего 2 записи на 27-м км., одна из которых с аномально высокой ценой и вторая с аномально низкой ..., по этой причине мы отвергаем данное наблюдение
#
# __кол-во наблюдений важный параметр для оценки качества данных — ты правильно отметил__

# %% [markdown]
# **Начиная с 23 километра и заканчивая 30, количество объявлений резко уменьшается, из-за чего на графике образуется провал. Данные восстановить не представляется возможным, так как для этого нужны дополнительные картографические данные. Медианным или средним значением, на мой взгяд, пропуски заполнять неккоректно. Изучаем питерские квартиры на 27 километре отдельно. Видно, что таких квартир всего две и одна из них имеет аномально низкую стоимость, всего 2 миллиона. Вероятно, оба эти фактора образуют провал на графике.**

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> После восстановления записей у нас вместо провала случился выброс ...
#
#         Начиная с 23 километра и заканчивая 30, количество объявлений резко уменьшается, из-за чего на графике образуется провал
#
# Направление мысли правильное
#
# У нас аномалия на питерских квартирах
#
# Для решения задачи
#
#         Стоит изучить записи, которые привели к провалу на 27-м км.
#
# стоит поправить фильтрацию данных: оставить только питерские квартиры и только с 27-го километра

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит посмотреть на количество квартир разных категорий (первый, последний, другой), которые продаются на 3-м км. и 5-ом ... и какую долю они занимают на каждом километре, чтобы объяснить пик  и провал в центре

# %%
filtered_data = df[df['cityCenters_nearest_km'].isin([3, 5])]
pivot_table = filtered_data.pivot_table(index='cityCenters_nearest_km', ё
                                        values='last_price', columns='floor_name', aggfunc='count')

proportions = pivot_table.apply(lambda x: x / x.sum() * 100, axis=1)
proportions = proportions.applymap(lambda x: f'{x:.1f}%')
proportions
# Out:
#   File "/tmp/ipykernel_522/81300724.py", line 3
#     values='last_price', columns='floor_name', aggfunc='count')
#     ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Появилась буква ё
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Широкие строки кода рекомендуется — делить <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a>.
#
# </div>

# %% [markdown]
# **Пик на 5-м километре может быть связан с более высоким процентом квартир в категории "первый", которые могут быть более престижными и иметь более высокую цену. Провал на 3-м километре может быть связан с более высоким процентом квартир в категории "другой", которые могут быть менее престижными или иметь более низкую цену.**

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Размер доли категорий квартир с более дешевой стоимостью намного больше на 3-м километре, чем на пятом, что является одной из причин падения и пика...
#
# возможно к этому фактору добавляются и другие

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Поправил все выводы, добавил необходимые расчеты. Надеюсь я правильно понял, что от меня требуется :)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Все отлично, осталось поправить шероховатости

# %% [markdown]
# **Чем ближе к центру оказался объект, тем выше его стоимость. Из графика видно, что примерно на десятом километре стоимость объектов начинает снижаться. В начале графика (расстояние 1-5 км от центра) средняя цена недвижимости достаточно высокая и колеблется в районе 9-10 миллионов рублей. После этого, на расстоянии 6-8 км от центра, средняя цена снижается до уровня около 8 миллионов рублей. Затем на расстоянии 9-16 км от центра цены продолжают снижаться, и достигают значения около 5-6 миллионов рублей. На расстоянии 17-18 км от центра наблюдается небольшой подъем в ценах, однако они остаются ниже 6 миллионов рублей. На расстоянии 19-25 км от центра цены продолжают колебаться в диапазоне от 4 до 5 миллионов рублей. На расстоянии 26 км от центра цены резко снижаются и достигают значения около 3.9 миллионов рублей. Однако на расстоянии 27 км от центра происходит резкий рост средней цены до 8.3 миллионов рублей, что может указывать на некоторую особенность или аномалию данных в этой области. После этого на расстояниях 28-29 км цены снова снижаются и возвращаются к значениям около 4.5-5 миллионов рублей.**

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# 1. Первоначальная обработка данных
#     * Типы столбцов balcony, is_apartment, first_day_exposition, days_exposition были приведены к подобающему виду
#     * Были устранены пропуски в столбцах balcony, is_apartment
#     * В столбце ceiling_height была найдена аномалия. Она была устранена, путём фильтрации высоты потолков в пределах от 2 до 4 метров. Тем самым, я устранил аномалию в данных.
#     * В столбце locality_name мной было найдено и устранено 12 неявных дубликатов.
#     * Были добавлены новые столбцы, для удобства анализа. Это цена одного квадратного метра (price_one_square), название этажа (floor_name), отдельные столбцы для дня, месяца и года размещения объявления (exposition_weekday, exposition_month, exposition_year) и столбец, где расстояние до центра указано в километрах (cityCenters_nearest_km).
# 2. Исследовательский анализ данных
#     1. Общий анализ столбцов
#         * total_area: В основном, превалируют квартиры с метражом от 30 до 65$м^2$.
#         * living_area: Большая часть объектов имеет жилую площадь от 15 до 30$м^2$. Объекты с жилой площадью больше 55$м^2$ встречаются уже реже.
#         * kitchen_area: Примерная площадь кухни составляет от 5 до 15$м^2$. Кухни с большей площадью встречаются реже.
#         * rooms: В основном преобладают квартиры с 1 до 3 комнат. Количество однушек может быть обусловлено тем, что на рынке много предложений квартир-студий.
#         * last_price: Большинство объектов имеют ценовой диапазон от 3 до 5 миллионов рублей. Вариантов больше или меньше этого диапазона немного. Наиболее частый вариант: 3.5 миллиона рублей.
#         * ceiling_height: После предварительной обработки данные о высоте потолков выглядят разумно, в рамках от 2 до 4 метров.
#         * floors_total: Больше всего преобладают частные дома, имеющие один этаж. Также весьма популярны пятиэтажки.
#         * floor_name: По количествам предложений, меньше всего занимаю первые и последние этажи (12.2% и 13.5% соответственно). Больше всего (74%) на рынке именно "середнячковых" этажей.
#         * cityCenters_nearest: Больше всего распространены квартиры, которые находятся от центра города на расстоянии от 10000м (10км) до 20000м (20км). Дальше уже идут менее популярные пригороды.
#         * airport_nearest: Аэропорты в среднем расположены на расстоянии от 15000м (15км) до 40000м (40км)
#         * parks_nearest: Парки от квартир расположены на расстоянии от 100м до 1000м.
#         * exposition_weekday: В основном объявления размещаются в рабочие дни. В выходные активность публикаций падает.
#         * exposition_month: В основном объявления публикуют в период с февраля по апрель, после чего активность снижается. Начиная с сентября и заканчивая ноябрем, активность публикаций снова растёт.
#     2. Анализ зависимостей и корреляций
#         *  Я убрал из датафрейма 224 строки, которые являются выбросами и избавились от правого хвоста. В результате анализа данных, я пришел к выводу, что быстрая продажа - это та, которая случилась до 22 дней, нормальная продажа - та, которая случилась от 22 до 189 дней, долгая продажа - та, которая происходит дольше 189 дней. Среднее - 142, медиана - 71.
#         * В результате анализа данных, я пришёл к выводу, что на полную стоимость объекта влияет общая площадь объекта (коэффициент корреляции 0.64) и расположение квартиры на этаже. Первый этаж оказался самым дешёвым, а все, что оказалось выше оказалось дороже. В результате исследования зависимости цены объекта от даты (день, месяц и год), я пришел к выводу, что ни один из этих параметров напрямую не влияет на среднюю цену объекта. Количество объявлений за 2015 год резко увеличилось, цены снизились, однако в дальнейшем мы можем наблюдать, что ценообразование остается на одном и том же уровне, не смотря на рост количества объявлений. Ровно тоже самое можно сказать и о средней площади объекта.
#         * В результате исследования данных, я сделал вывод, что самая большая стоимость квадратного метра в Санкт-Петербугре, а самая низкая в Выборге.
#         * Чем ближе к центру оказался объект, тем выше его стоимость. Из графика видно, что примерно на десятом километре стоимость объектов начинает снижаться. В начале графика (расстояние 1-5 км от центра) средняя цена недвижимости достаточно высокая и колеблется в районе 9-10 миллионов рублей. После этого, на расстоянии 6-8 км от центра, средняя цена снижается до уровня около 8 миллионов рублей. Затем на расстоянии 9-16 км от центра цены продолжают снижаться, и достигают значения около 5-6 миллионов рублей. На расстоянии 17-18 км от центра наблюдается небольшой подъем в ценах, однако они остаются ниже 6 миллионов рублей. На расстоянии 19-25 км от центра цены продолжают колебаться в диапазоне от 4 до 5 миллионов рублей. На расстоянии 26 км от центра цены резко снижаются и достигают значения около 3.9 миллионов рублей. Однако на расстоянии 27 км от центра происходит резкий рост средней цены до 8.3 миллионов рублей, что может указывать на некоторую особенность или аномалию данных в этой области. После этого на расстояниях 28-29 км цены снова снижаются и возвращаются к значениям около 4.5-5 миллионов рублей.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />?
#
#         ceiling_height: После предварительной обработки данные о высоте потолков выглядят разумно, в рамках от 3 до 5 метров.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Провел все необходимые перерасчёты, добавил недостающие графики. Спасибо за подробное ревью!

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Технически вывод хороший, есть сравнения показателей, инсайты, анализ рынка недвижимости, молодец
#
# Осталось перепроверить итоговый вывод после исправления всех комментариев

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Можно на "ты", да. Исправил вывод и постарался исправить все замечания к моему проекту. Спасибо за подробное ревью и указание на ошибки, а также за полезные ссылки. Надеюсь на скорейшее повторное ревью!

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Выполнил исследовательскую работу, молодец
#
# Критические ❌ комментарии
#
#
# + сменить тип данных
# + настроить фильтрацию редких значений в п. 2.4
# + подправить гистограммы в п.4.1
# + пересчитать скорость продаж
# + добавить графики в п. 4.3
# + добавить вывод в п. 4.3
# + поправить выполнение и исследовать аномалии в п.4.5
# + поправить итоговый вывод
#
#
#
# С ними важно поработать и исправить
#
# Стоит обратить внимание и на такие комментарии ⚠️
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)
#
# <p> Доп. материал: методы группировки и расчета суммы, средних и т.д.
#
# [Подробное руководство по группировке и агрегированию с помощью pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%B4%D1%80%D0%BE%D0%B1%D0%BD%D0%BE%D0%B5%20%D1%80%D1%83%D0%BA%D0%BE%D0%B2%D0%BE%D0%B4%D1%81%D1%82%D0%B2%D0%BE%20%D0%BF%D0%BE%20%D0%B3%D1%80%D1%83%D0%BF%D0%BF%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B5%20%D0%B8%20%D0%B0%D0%B3%D1%80%D0%B5%D0%B3%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8E%20%D1%81%20%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D1%8C%D1%8E%20pandas.html)
#
#  Интересная функция в библиотеке пандаса
#
# [Понимание функции transform в Pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%BD%D0%B8%D0%BC%D0%B0%D0%BD%D0%B8%D0%B5%20%D1%84%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D0%B8%20transform%20%D0%B2%20Pandas.html)
#
# [Как выбрать определенные столбцы из DataFrame](https://dfedorov.spb.ru/pandas/03.%20%D0%9A%D0%B0%D0%BA%20%D0%B2%D1%8B%D0%B1%D1%80%D0%B0%D1%82%D1%8C%20%D0%BF%D0%BE%D0%B4%D0%BC%D0%BD%D0%BE%D0%B6%D0%B5%D1%81%D1%82%D0%B2%D0%BE%20%D0%B8%D0%B7%20DataFrame_.html?ysclid=l9sps5lt6g576766938)
#
# [How to visualise data using histograms in Pandas](https://practicaldatascience.co.uk/data-science/how-to-visualise-data-using-histograms-in-pandas)

# %% [markdown]
# ### Бонус

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />Диаграмма рассеяния

# %%
# check
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# check
sns.pairplot(data[['last_price', 'total_area', 'rooms', 'cityCenters_nearest']])
plt.gcf().set_size_inches(12,12);

# %%
# check
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='last_price' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'b', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — цена трешки')


data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter', 
        y='last_price' , x='living_area', alpha=0.5, figsize=(15,8), c = 'r', s = 4)
plt.title('Диаграмма рассеяния — Жилая площадь — цена трешки');

# %%
# check
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='living_area' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'g', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — Жилая');

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
